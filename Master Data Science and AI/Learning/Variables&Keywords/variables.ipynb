# %% [markdown]
# Variable and Keyword:
#
# - a python variable is a reserved memory location to store value.
# - in other words in Python program , a variable gives data to the computer for processing.

# %%
my_name = 'Soumyajeet Nayak'
print(my_name)
print(type(my_name))

my_age = 24
print(my_age) 
# my age is the variable to store the age of the user.
# to find the type of the variable we use TYPE()

type(my_age)
# Out:
# Soumyajeet Nayak
# <class 'str'>
# 24
# int

# %% [markdown]
# # 1, 2, 3, 4,5, 6 ..... -> this is integer type
# # 1.1 ,2.1 ,3.1 ..... -> this is Float type
# # hello , world , soumayjeet , nayak , .... -> this is String type
# # true , false , True , False , .... -> this is Boolean type

# %%
score = 89.4
print(score)
type(score)
# score
# in the above line SCORE it works like print(score) but it is not a print statement. it is a variable that stores the value

# round(score)

new_score = "15.19"
print(new_score)
type(new_score)
# Out:
# 89.4
# 15.19
# str

# %%
var = "Hello this is a variable that stores a string value"
# var = 11
print(var)
type(var)

# in python it take the last updated value provided to the variable

# if i write var =10
var = 10
print(var)
# Out:
# Hello this is a variable that stores a string value
# 10
