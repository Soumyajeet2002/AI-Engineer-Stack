# %%
a = 17
b = 5

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a**2)
# Out:
# 22
# 12
# 85
# 3.4
# 3
# 2
# 289

# %%
result = 10 + 5 * 2**2

print(result)
# Out:
# 30

# %%
x = "100"
y = "20"

print(x + y)
print(int(x) + int(y))
# Out:
# 10020
# 120

# %%
print(int(10.9))
print(float(10))
print(str(25))
print(bool(1))
print(bool(0))
print(bool(""))
print(bool("False"))
# Out:
# 10
# 10.0
# 25
# True
# False
# False
# True

# %%
x = "10"
y = 10

print(x == y)
print(int(x) == y)
print(x == str(y))
# Out:
# False
# True
# True

# %%
a = 10
b = 20

print(a > 5 and b > 15)
print(a > 15 and b > 15)
print(a > 15 or b > 15)
print(not (a > 5))
# Out:
# True
# False
# True
# False

# %%
age = input("Enter your age: ")
number = input("Enter a number: ")

age = int(age)
number = float(number)

result = age + number * 2

print(result)
print(type(result))

print(age > number)
print(str(age) + str(number))
# Out:
# 34.0
# <class 'float'>
# True
# 245.0
